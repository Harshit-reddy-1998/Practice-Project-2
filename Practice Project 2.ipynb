# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('world_happiness_report.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Country']=le.fit_transform(df['Country'])
df['Region']=le.fit_transform(df['Region'])

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# We have 158 rows and 12 columns in a dataset.

# %%
df.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# We have int type values in country, region and Happiness rank columns. In the rest of the columns, we have float type values.

# %% [markdown]
# # Summary statistics

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# There is a large difference in the 75th percentile and max in country and happiness rank.

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # To check Correlation

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(dfcorr,cmap='GnBu',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dark shades are highly correlated and light shades are negatively correlated.

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
plt.boxplot(df['Country'])
plt.show()

# %% [markdown]
# There are no outliers present in this column.

# %%
plt.boxplot(df['Region'])
plt.show()

# %% [markdown]
# There are no outliers present in this column.

# %%
plt.boxplot(df['Happiness Rank'])
plt.show()

# %% [markdown]
# There are no outliers present in this column.

# %%
plt.boxplot(df['Standard Error'])
plt.show()

# %% [markdown]
# There are some outliers present in this column.

# %%
plt.boxplot(df['Economy (GDP per Capita)'])
plt.show()

# %% [markdown]
# There are no outliers present in this column.

# %%
plt.boxplot(df['Family'])
plt.show()

# %% [markdown]
# There are some outliers present in this column.

# %%
plt.boxplot(df['Health (Life Expectancy)'])
plt.show()

# %% [markdown]
# There are no outliers present in this column.

# %%
plt.boxplot(df['Freedom'])
plt.show()

# %% [markdown]
# There are no outliers present in this column.

# %%
plt.boxplot(df['Trust (Government Corruption)'])
plt.show()

# %% [markdown]
# There are some outliers present in this column.

# %%
plt.boxplot(df['Generosity'])
plt.show()

# %% [markdown]
# There are some outliers present in this column.

# %%
sns.distplot(df['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Density'>

# %% [markdown]
# Data is normally distributed in this column.

# %%
sns.distplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed in this column.

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %% [markdown]
# Data is normally distributed in this column.

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %% [markdown]
# Data is normally distributed in this column.

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed in this column.

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %% [markdown]
# Data is normally distributed in this column.

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed in this column.

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %% [markdown]
# Data is normally distributed in this column.

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed in this column.

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# Data is normally distributed in this column.

# %% [markdown]
# # Bi-Variate Analysis

# %%
plt.scatter(df['Country'],df['Happiness Score'])

# %%
plt.scatter(df['Region'],df['Happiness Score'])

# %%
plt.scatter(df['Happiness Rank'],df['Happiness Score'])

# %%
plt.scatter(df['Standard Error'],df['Happiness Score'])

# %%
plt.scatter(df['Economy (GDP per Capita)'],df['Happiness Score'])

# %%
plt.scatter(df['Family'],df['Happiness Score'])

# %%
plt.scatter(df['Health (Life Expectancy)'],df['Happiness Score'])

# %%
plt.scatter(df['Freedom'],df['Happiness Score'])

# %%
plt.scatter(df['Trust (Government Corruption)'],df['Happiness Score'])

# %%
plt.scatter(df['Generosity'],df['Happiness Score'])

# %%
sns.histplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Count'>

# %%
sns.histplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Count'>

# %%
sns.histplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Count'>

# %%
sns.histplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Count'>

# %%
sns.histplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Count'>

# %%
sns.histplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Count'>

# %%
sns.histplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Count'>

# %%
sns.histplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Count'>

# %% [markdown]
# # Multi-variate Analysis

# %%
sns.pairplot(df)

# %%
import numpy as np
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.23877001, 1.30025593, 1.72099989, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [0.44946522, 1.30025593, 1.69907456, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [0.90989302, 1.30025593, 1.67714922, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.26069514, 0.37544095, 1.67742676, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.26069514, 0.96511655, 1.69935209, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.37032081, 0.96511655, 1.72127743, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
Threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
z[40][4]
# Out:
# 3.5727739331415806

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df1.shape
# Out:
# (149, 12)

# %% [markdown]
# So, 9 rows have been removed since the outliers were present.

# %%
x=df1.drop(['Happiness Score'],axis=1)
y=df1.iloc[:,3]

# %%
x.head()
# Out:
#    Country  Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0      135       9               1         0.03411                   1.39651
# 1       58       9               2         0.04884                   1.30232
# 2       37       9               3         0.03328                   1.32548
# 3      105       9               4         0.03880                   1.45900
# 4       24       5               5         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
x.shape
# Out:
# (149, 11)

# %%
y.shape
# Out:
# (149,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=43)

# %%
x_train.shape
# Out:
# (99, 11)

# %%
x_test.shape
# Out:
# (50, 11)

# %%
y_train.shape
# Out:
# (99,)

# %%
y_test.shape
# Out:
# (50,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-4.76836279e-07, -2.89662305e-06, -9.06820380e-06, -9.33064827e-04,
#         9.99696462e-01,  9.99713411e-01,  9.99434751e-01,  9.98988620e-01,
#         1.00009351e+00,  9.99643949e-01,  9.99605705e-01])

# %%
lr.intercept_
# Out:
# 0.0030339876071794336

# %%
lr.score(x_train,y_train)
# Out:
# 0.9999999524628677

# %%
pred=lr.predict(x_test)
print('Predicted data',pred)
print('Actual data',y_test)
# Out:
# Predicted data [5.69524574 4.97116592 4.78791858 6.29482171 5.82406765 6.26912205
#  5.81265607 3.84500479 6.4850877  5.97528643 5.19237575 4.79961303
#  7.2255234  5.19380547 4.8975893  6.98255145 7.19970016 4.0331408
#  5.36019903 3.89655223 7.56066019 5.47695874 4.36915319 4.94880006
#  6.94021587 4.85759946 7.52700966 7.27754299 4.88452767 6.90130934
#  4.68553552 4.73855231 6.13019143 5.87831904 4.64230916 5.58862419
#  4.51711027 4.55062124 5.54827075 4.87427293 5.79055605 6.81010644
#  4.27058915 3.81913485 3.90379014 4.21849854 4.83919027 5.42867562
#  5.19246175 5.12315947]
# Actual data 65     5.695
# 93     4.971
# 104    4.788
# 38     6.295
# 57     5.824
# 39     6.269
# 58     5.813
# 143    3.845
# 31     6.485
# 47     5.975
# 81     5.192
# 103    4.800
# 11     7.226
# 80     5.194
# 96     4.898
# 15     6.983
# 12     7.200
# 136    4.033
# 74     5.360
# 142    3.896
# 1      7.561
# 70     5.477
# 125    4.369
# 95     4.949
# 17     6.940
# 101    4.857
# ...

# %%
print('error:')

print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 0.00028379958433435884
# Mean squared error: 1.050726764939859e-07
# Root Mean squared error: 0.0003241491577869452

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.999999901963041
